# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from skimage import io
from skimage.transform import resize



# Load the saved model
model = tf.keras.models.load_model('model_for_nuclei.keras', custom_objects={'Lambda': tf.keras.layers.Lambda}, compile=False, safe_mode=False)

# Load your test data (replace this with your actual test data)
img = io.imread("data/test/images/Block_1C1_Row_1_Middle_728.png")
#test_data = resize(img, (128, 128), mode='constant', preserve_range=True)


# Make predictions on the test data
#pred = model.predict(test_data)

# Plot the predictions
plt.figure(figsize=(10, 6))
plt.imshow(img, cmap='gray')  # Assuming grayscale masks
plt.title('Predicted Mask')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 14
#      12 img = io.imread("data/test/images/Block_1C1_Row_1_Middle_728.png")
#      13 #test_data = resize(img, (128, 128), mode='constant', preserve_range=True)
# ---> 14 pickle.dump(model, open('model.pkl','wb'))
#      15 model=pickle.load(open('model.pkl','rb'))
#      17 # Make predictions on the test data
#      18 #pred = model.predict(test_data)
#      19
#      20 # Plot the predictions
#
# AttributeError: Can't pickle local object 'Layer._initialize_tracker.<locals>.<lambda>'

# %%
pip install matplotlib
# Out:
# ...
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\Mayank\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.8 kB ? eta -:--:--
#      --------- --------------------------- 41.0/162.8 kB 653.6 kB/s eta 0:00:01
#      -------------------------- ----------- 112.6/162.8 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 162.8/162.8 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#     --------------------------------------- 0.1/7.7 MB 4.0 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/7.7 MB 3.8 MB/s eta 0:00:02
# ...

# %%
pip install scikit-image
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.6 kB 495.5 kB/s eta 0:00:01
#      -------------------------------------- 60.6/60.6 kB 645.4 kB/s eta 0:00:00
# ...
#   Using cached imageio-2.34.1-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------------------- 0.1/12.8 MB 1.7 MB/s eta 0:00:08
#     --------------------------------------- 0.3/12.8 MB 2.1 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/12.8 MB 2.6 MB/s eta 0:00:05
#    -- ------------------------------------- 0.7/12.8 MB 3.4 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/12.8 MB 3.6 MB/s eta 0:00:04
# ...
